# %%
import pandas as pd
import numpy as np

# %%
playersDf = pd.read_csv("merged_players.csv")
teamsWithWinDf = pd.read_csv("teamsWithWin.csv")
playersDf["person_id"] = playersDf["person_id"].astype(str)

# %%
# Now explode the dataframe
# Player id column is string for some reason, hence first convert into a list 
teamsWithWinDf.player_id = teamsWithWinDf.player_id.str[1:-1].str.split(',').tolist()
expandedTeamsWithWinDf = teamsWithWinDf.explode('player_id').reset_index()
expandedTeamsWithWinDf['player_id'] = expandedTeamsWithWinDf['player_id'].apply(lambda x: x.strip())

# %%
# teamsWithWinDf["player_id"][0]
expandedTeamsWithWinDf.player_id.dtype
# Out:
# dtype('O')

# %%
# Now join with the player stats
joinedTable = pd.merge(expandedTeamsWithWinDf, playersDf, left_on="player_id", right_on="person_id")
joinedTable
# Out:
#         index  Unnamed: 0_x   game_id winning_team_abbr team_id_x player_id  \
# 0           0             0  29600012               LAL       LAL       716
# 1           0             0  29600012               LAL       LAL       224
# 2           0             0  29600012               LAL       LAL         2
# 3           0             0  29600012               LAL       LAL        89
# 4           0             0  29600012               LAL       LAL       965
# ...       ...           ...       ...               ...       ...       ...
# 261999  59635         59635  42200236               LAL       LAL      2544
# 262000  59643         59643  42200312               DEN       LAL      2544
# 262001  59659         59659  42200403               DEN       MIA      2617
# 262002  59663         59663  32200001               GNS       LBN      2544
# 262003  59665         59665  32200001               GNS       LBN      2544
#
#         Unnamed: 0_y      ilkid first_name last_name  ...       playercode  \
# 0               2055  ROBINRU01     rumeal  robinson  ...  rumeal_robinson
# 1               1237  JONESED01      eddie     jones  ...      eddie_jones
# 2               2153  SCOTTBY01      byron     scott  ...      byron_scott
# 3               2463  VANEXNI01       nick  van exel  ...    nick_van exel
# 4                741  FISHEDE01      derek    fisher  ...     derek_fisher
# ...              ...        ...        ...       ...  ...              ...
# 261999          1170  JAMESLE01     lebron     james  ...     lebron_james
# 262000          1170  JAMESLE01     lebron     james  ...     lebron_james
# 262001          1002  HASLEUD01     udonis    haslem  ...    udonis_haslem
# 262002          1170  JAMESLE01     lebron     james  ...     lebron_james
# 262003          1170  JAMESLE01     lebron     james  ...     lebron_james
#
#         from_year  to_year  dleague_flag  nba_flag  games_played_flag  \
# 0          1990.0   1996.0             N         Y                  Y
# 1          1994.0   2007.0             N         Y                  Y
# 2          1983.0   1996.0             N         Y                  Y
# 3          1993.0   2005.0             N         Y                  Y
# 4          1996.0   2013.0             N         Y                  Y
# ...           ...      ...           ...       ...                ...
# 261999     2003.0   2023.0             N         Y                  Y
# 262000     2003.0   2023.0             N         Y                  Y
# 262001     2003.0   2023.0             N         Y                  Y
# 262002     2003.0   2023.0             N         Y                  Y
# 262003     2003.0   2023.0             N         Y                  Y
#
#        draft_year draft_round  draft_number greatest_75_flag
# 0            1990           1            10                N
# 1            1994           1            10                N
# 2            1983           1             4                N
# 3            1993           2            37                N
# 4            1996           1            24                N
# ...           ...         ...           ...              ...
# 261999       2003           1             1                Y
# 262000       2003           1             1                Y
# 262001  Undrafted   Undrafted     Undrafted                N
# 262002       2003           1             1                Y
# 262003       2003           1             1                Y
#
# [262004 rows x 50 columns]

# %%
joinedTable["player_id"].nunique()
# Out:
# 816

# %%
joinedTable.to_csv("player_with_game_id.csv")
