# %%
import pandas as pd
import numpy as np

# %%
playerNormalizedDf = pd.read_csv("player_regular_season_normalized.csv", index_col=0)
gameWithWinDf = pd.read_csv("team_with_year.csv", index_col=0)

# %%
gameWithWinDf.keys()
# Out:
# Index(['game_date', 'team_id_x', 'game_id', 'ilkid'], dtype='object')

# %%
playerNormalizedDf.keys()
# Out:
# Index(['ilkid', 'year', 'firstname', 'lastname', 'team', 'leag', 'gp',
#        'minutes', 'pts', 'oreb', 'dreb', 'reb', 'asts', 'stl', 'blk',
#        'turnover', 'pf', 'fga', 'fgm', 'fta', 'ftm', 'tpa', 'tpm'],
#       dtype='object')

# %% [markdown]
# ## Food for thought
# Till where do we have the data? Is it till Dec 2004, Dec 2005 or Dec 2003 or something else? Need to figure this out

# %%
gameWithWinDf
# Out:
#         game_date team_id_x   game_id  \
# 0      1996-11-01       ATL  29600005
# 1      1996-11-01       BOS  29600001
# 2      1996-11-01       CHI  29600001
# 3      1996-11-01       CLE  29600002
# 4      1996-11-01       DAL  29600010
# ...           ...       ...       ...
# 20142  2005-12-31       NOK  20500869
# 20143  2005-12-31       POR  20500435
# 20144  2005-12-31       SAS  20500431
# 20145  2005-12-31       SEA  20500437
# 20146  2005-12-31       UTA  20500436
#
#                                                    ilkid
# 0      ['LAETTCH01', 'BLAYLMO01', 'BARRYJO01', 'NORMA...
# 1      ['FOXRI01', 'WESLEDA01', 'ELLISPE01', 'WILLIER...
# 2      ['BROWNRA01', 'JORDAMI01', 'RODMADE01', 'BUECH...
# 3      ['GEARYRE01', 'THOMACA01', 'POTAPVI01', 'LANGA...
# 4      ['HARPEDE01', 'DUMASTO01', 'GATLICH01', 'KIDDJ...
# ...                                                  ...
# 20142  ['BROWNPJ01', 'CLAXTSP01', 'MASONDE01', 'WESTD...
# ...

# %%
import ast
gameWithWinDf['ilkid'] = gameWithWinDf['ilkid'].apply(ast.literal_eval)

# %%
gameWithWinDf_exploded = gameWithWinDf.explode(column="ilkid")

# %%
playerNormalizedDf = playerNormalizedDf[playerNormalizedDf["year"] >= 1995]
playerNormalizedDf
# Out:
#            ilkid  year firstname    lastname team leag  gp  minutes    pts  \
# 13816  ABDULMA01  1995     Mahmo  Abdul-rauf  DEN    N  57    35.60  19.21
# 13817  ADAMSMI01  1995   Michael       Adams  CHA    N  21    15.67   5.43
# 13818  ADDISRA01  1995    Rafael     Addison  CHA    N  53     9.74   3.23
# 13819  ALEXACO01  1995      Cory   Alexander  SAS    N  60     9.33   2.80
# 13820  ALLENJE01  1995    Jerome       Allen  MIN    N  41     8.83   2.63
# ...          ...   ...       ...         ...  ...  ...  ..      ...    ...
# 19107  WILLISC01  2004     Scott    Williams  CLE    N  19     8.00   1.74
# 19108  WOODSLO01  2004     Loren       Woods  TOR    N  45    15.82   3.91
# 19109  WOODSQY01  2004    Qyntel       Woods  MIA    N   3    13.33   3.33
# 19110  WRIGHDO01  2004    Dorell      Wright  MIA    N   3     9.00   2.33
# 19111  WRIGHLO02  2004  Lorenzen      Wright  MEM    N  80    28.59   9.64
#
# ...

# %% [markdown]
# If we want only x prior years we can do something like this
#
# ```
# import pandas as pd
#
# # Example DataFrame
# data = {
#     'year': [2003, 2003, 2004, 2004, 2005, 2005],
#     'player_id': ['abc', 'def', 'abc', 'def', 'abc', 'def'],
#     'points': [10, 15, 20, 25, 30, 35]
# }
# df = pd.DataFrame(data)
#
# # Sort DataFrame by 'year'
# df.sort_values(by='year', inplace=True)
#
# # Calculate average points scored prior to each year
# df['avg_points_prior'] = (
#     df.groupby('player_id')['points']
#     .transform(lambda x: (x.shift(1) + x.shift(2)) / 2)
# )
#
# print(df)
# ```

# %%
# I want to calculate a cummalative table where a player stats for 1996 for ex is the stat of 1995
playerNormalizedDf.sort_values("year", inplace=True)

# Get all columns for cummalative sume
column_names = playerNormalizedDf.columns.to_list()
relevant_columns = column_names[6:]

# Find cummalative sum for each player for each stat
playerNormalizedDf['count'] = playerNormalizedDf.groupby('ilkid').cumcount() + 1
for col in relevant_columns:
    playerNormalizedDf[f'{col}_cumsum'] = playerNormalizedDf.groupby('ilkid')[col].cumsum()
    playerNormalizedDf[f'avg_{col}'] = playerNormalizedDf[f'{col}_cumsum'] / playerNormalizedDf['count']

# %%
playerNormalizedDf
# Out:
#            ilkid  year firstname    lastname team leag  gp  minutes    pts  \
# 13816  ABDULMA01  1995     Mahmo  Abdul-rauf  DEN    N  57    35.60  19.21
# 14188  PIPPESC01  1995   Scottie      Pippen  CHI    N  77    36.69  19.43
# 14187  PINCKED01  1995        Ed    Pinckney  PHI    N  27    25.15   5.56
# 14186  PINCKED01  1995        Ed    Pinckney  TOT    N  74    23.11   6.46
# 14185  PINCKED01  1995        Ed    Pinckney  TOR    N  47    21.94   6.98
# ...          ...   ...       ...         ...  ...  ...  ..      ...    ...
# 18723   GILLKE01  2004   Kendall        Gill  MIL    N  14    20.29   6.07
# 18724  GINOBEM01  2004  Emmanuel    Ginobili  SAS    N  74    29.64  16.03
# 18725  GIRICGO01  2004    Gordan     Giricek  UTA    N  81    20.49   8.83
# 18709  FRAHMRI01  2004    Richie       Frahm  POR    N  43    11.60   3.81
# 19111  WRIGHLO02  2004  Lorenzen      Wright  MEM    N  80    28.59   9.64
#
# ...

# %%
# merged_df = pd.merge(left=playerNormalizedDf, right=gameWithWinDf_exploded, left_on=["ilkid", "year"], right_on=["ilkid","game_date"])
# merged_df[merged_df["firstname"] == "Qyntel"]

# %%
playerNormalizedDf.to_csv("cumilative_player_attributes.csv")

# %%
playerNormalizedDf["team"].unique()
# Out:
# array(['DEN', 'CHI', 'PHI', 'TOT', 'TOR', 'IND', 'LAC', 'CLE', 'PHO',
#        'SAS', 'NJN', 'SEA', 'SAC', 'WA1', 'LAL', 'DAL', 'CHA', 'MIA',
#        'UTA', 'MIL', 'ORL', 'MIN', 'POR', 'NYK', 'DET', 'VAN', 'HOU',
#        'BOS', 'GSW', 'ATL', 'WAS', 'MEM', 'NOH', 'CHR'], dtype=object)
